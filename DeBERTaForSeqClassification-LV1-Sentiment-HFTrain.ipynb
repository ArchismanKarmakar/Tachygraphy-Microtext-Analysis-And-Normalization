# %% [markdown]
# <a href="https://www.kaggle.com/code/archismancoder/debertaforseqclassification-lv1-sentiment-hftrain?scriptVersionId=226582854" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dataset-tachygraphy/Tachygraphy_EmotionMoodtags_Dataset.csv
# /kaggle/input/dataset-tachygraphy/Tachygraphy_MicroText-AIO-V3.xlsx
# /kaggle/input/dataset-tachygraphy/Tachygraphy_MicroText-AIO-Emotion_Mood_Tags-V3.xlsx
# /kaggle/input/dataset-tachygraphy/Tachygraphy_dataset_main.csv
# /kaggle/input/dataset-tachygraphy/Tachygraphy_MicroText-AIO-Sentiment_Polarities_3_Label-V3.xlsx
# /kaggle/input/dataset-tachygraphy/Tachygraphy_MicroText-AIO-Sentiment_Polarities_2_Label-V3 (Neutral Omitted).xlsx
# /kaggle/input/dataset-tachygraphy/Tachygraphy_MicroText-AIO-V2.xlsx

# %% [markdown]
# # DATASET & PREPROCESSING

# %%
import emoji
from bs4 import BeautifulSoup
import os
import re
import string
import json

'''For emoji cleaning'''
# Out:
# 'For emoji cleaning'

# %%
dataset = pd.read_excel('/kaggle/input/dataset-tachygraphy/Tachygraphy_MicroText-AIO-Sentiment_Polarities_3_Label-V3.xlsx')

# %%
df=dataset

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", 
                       "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", 
                       "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", 
                       "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am",
                       "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", 
                       "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have",
                       "it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not",
                       "mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", 
                       "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                       "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", 
                       "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have",
                       "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is",
                       "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would",
                       "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have",
                       "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have",
                       "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", 
                       "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did",
                       "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", 
                       "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", 
                       "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                       "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have",
                       "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have", 'u.s':'america', 'e.g':'for example'}

punct = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£', 
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', 
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', 
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', 
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]

punct_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2", "—": "-", "–": "-", "’": "'", "_": "-",
                 "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 
                 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', '!':' '}

mispell_dict = {'colour': 'color', 'centre': 'center', 'favourite': 'favorite', 'travelling': 'traveling', 'counselling': 'counseling', 'theatre': 'theater',
                'cancelled': 'canceled', 'labour': 'labor', 'organisation': 'organization', 'wwii': 'world war 2', 'citicise': 'criticize', 'youtu ': 'youtube ',
                'Qoura': 'Quora', 'sallary': 'salary', 'Whta': 'What', 'narcisist': 'narcissist', 'howdo': 'how do', 'whatare': 'what are', 'howcan': 'how can',
                'howmuch': 'how much', 'howmany': 'how many', 'whydo': 'why do', 'doI': 'do I', 'theBest': 'the best', 'howdoes': 'how does', 
                'mastrubation': 'masturbation', 'mastrubate': 'masturbate', "mastrubating": 'masturbating', 'pennis': 'penis', 'Etherium': 'Ethereum', 
                'narcissit': 'narcissist', 'bigdata': 'big data', '2k17': '2017', '2k18': '2018', 'qouta': 'quota', 'exboyfriend': 'ex boyfriend', 
                'airhostess': 'air hostess', "whst": 'what', 'watsapp': 'whatsapp', 'demonitisation': 'demonetization', 'demonitization': 'demonetization',
                'demonetisation': 'demonetization'}

def clean_text(text):
    '''Clean emoji, Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
#     text = emoji.demojize(text)
#     text = re.sub(r'\:(.*?)\:','',text)
#     text = str(text).lower()    #Making Text Lowercase
#     text = re.sub('\[.*?\]', '', text)
    #The next 2 lines remove html text
    text = BeautifulSoup(text, 'lxml').get_text()
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('\n', '', text)
#     text = re.sub('\w*\d\w*', '', text)
    # replacing everything with space except (a-z, A-Z, 0-9, "%", ".", "&", ",", "'", "?", "!", ",", "'", ";", "-")
    text = re.sub(r"[^a-zA-Z0-9?.!,¿'%&,';-]+", " ", text)
    return text

def clean_contractions(text, mapping):
    '''Clean contraction using contraction mapping'''    
    specials = ["’", "‘", "´", "`"]
    for s in specials:
        text = text.replace(s, "'")
    for word in mapping.keys():
        if ""+word+"" in text:
            text = text.replace(""+word+"", ""+mapping[word]+"")
    #Remove Punctuations
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    text = re.sub(r"([?.!,¿])", r" \1 ", text)
    text = re.sub(r'[" "]+', " ", text)
    return text

def clean_special_chars(text, punct, mapping):
    '''Cleans special characters present(if any)'''   
    for p in mapping:
        text = text.replace(p, mapping[p])
    
    for p in punct:
        text = text.replace(p, f' {p} ')
    
    specials = {'\u200b': ' ', '…': ' ... ', '\ufeff': '', 'करना': '', 'है': ''}  
    for s in specials:
        text = text.replace(s, specials[s])
    
    return text

def correct_spelling(x, dic):
    '''Corrects common spelling errors'''   
    for word in dic.keys():
        x = x.replace(word, dic[word])
    return x

def remove_space(text):
    '''Removes awkward spaces'''   
    #Removes awkward spaces 
    text = text.strip()
    text = text.split()
    return " ".join(text)

def text_preprocessing_pipeline(text):
    '''Cleaning and parsing the text.'''
#     text = clean_contractions(text, contraction_mapping)
    text = clean_text(text)
#     text = clean_contractions(text, contraction_mapping)
#     text = clean_special_chars(text, punct, punct_mapping)
#     text = correct_spelling(text, mispell_dict)
    text = remove_space(text)
    return text

# %%
df['Informal Text']
# Out:
# 0                           omg, JEE prep is killing me rn
# 1                         u up 4 a break b4 UPSC revision?
# 2                              ttyl, finishing da CAT mock
# 3                        nah, dat GATE paper was brutal af
# 4                        sup? u done w/ ur IIT assignment?
#                                ...
# 10275          bruh, UP’s power cuts, no relief in sight 🔌
# 10276    wtf, new tax laws hitting hard, prices gonna j...
# 10277    yo, Adani’s stock falling, more issues surfaci...
# 10278      bruh, tech IPOs doing well, investors excited 📉
# 10279    wtf, Delhi’s AQI at record highs, air quality ...
# Name: Informal Text, Length: 10280, dtype: object

# %%
df['Informal Text'] = df['Informal Text'].astype(str)
# df['anger'] = df['anger'].astype(float)
# df['disgust'] = df['disgust'].astype(float)
# df['fear'] = df['fear'].astype(float)
# df['joy'] = df['joy'].astype(float)
# df['neutral'] = df['neutral'].astype(float)
# df['sadness'] = df['sadness'].astype(float)
# df['surprise'] = df['surprise'].astype(float)

# %%
df['Sentiment'] = df['Sentiment'].astype(str)

# %%
df['Informal Text'] = df['Informal Text'].apply(lambda x: text_preprocessing_pipeline(x))
df['Sentiment'] = df['Sentiment'].apply(lambda x: text_preprocessing_pipeline(x))
# Out:
# <ipython-input-5-93bb6d8e489f>:51: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, 'lxml').get_text()

# %%
df['Informal Text']
# Out:
# 0                           omg, JEE prep is killing me rn
# 1                         u up 4 a break b4 UPSC revision?
# 2                              ttyl, finishing da CAT mock
# 3                        nah, dat GATE paper was brutal af
# 4                         sup? u done w ur IIT assignment?
#                                ...
# 10275            bruh, UP s power cuts, no relief in sight
# 10276    wtf, new tax laws hitting hard, prices gonna jump
# 10277     yo, Adani s stock falling, more issues surfacing
# 10278        bruh, tech IPOs doing well, investors excited
# 10279    wtf, Delhi s AQI at record highs, air quality ...
# Name: Informal Text, Length: 10280, dtype: object

# %%
df.drop(columns=['Expanded Meaning'], inplace=True)

# %%
bin_polar = pd.get_dummies(df['Sentiment'], prefix='', prefix_sep='')

# %%
bin_polar = bin_polar.astype(int)

# %%
bin_polar
# Out:
#        negative  neutral  positive
# 0             1        0         0
# 1             0        1         0
# 2             0        1         0
# 3             1        0         0
# 4             0        1         0
# ...         ...      ...       ...
# 10275         1        0         0
# 10276         1        0         0
# 10277         1        0         0
# 10278         0        0         1
# 10279         1        0         0
#
# [10280 rows x 3 columns]

# %%
df = pd.concat([df, bin_polar], axis=1)
df.head()
# Out:
#                        Informal Text Sentiment  negative  neutral  positive
# 0     omg, JEE prep is killing me rn  negative         1        0         0
# 1   u up 4 a break b4 UPSC revision?   neutral         0        1         0
# 2        ttyl, finishing da CAT mock   neutral         0        1         0
# 3  nah, dat GATE paper was brutal af  negative         1        0         0
# 4   sup? u done w ur IIT assignment?   neutral         0        1         0

# %%
# df.drop(columns=['sentiment_polarity'], inplace=True)
df.head()
# Out:
#                        Informal Text Sentiment  negative  neutral  positive
# 0     omg, JEE prep is killing me rn  negative         1        0         0
# 1   u up 4 a break b4 UPSC revision?   neutral         0        1         0
# 2        ttyl, finishing da CAT mock   neutral         0        1         0
# 3  nah, dat GATE paper was brutal af  negative         1        0         0
# 4   sup? u done w ur IIT assignment?   neutral         0        1         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10280 entries, 0 to 10279
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Informal Text  10280 non-null  object
#  1   Sentiment      10280 non-null  object
#  2   negative       10280 non-null  int64
#  3   neutral        10280 non-null  int64
#  4   positive       10280 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 401.7+ KB

# %%
sentiment_polarity_label_mapping = {
    0: "negative", 1: "neutral", 2: "positive"
}

# %%
sentiment_polarity_label_mapping_rev = {
    'negative': 0, 'neutral': 1, 'positive': 2
}

# %%
SENTIMENT_POLARITY_LABELS = [
    "negative", "neutral", "positive"
]

# %%
def test_train_split(dataset, test_ratio=0.1):
  test_indices = np.random.rand(len(dataset)) < test_ratio
  return dataset[~test_indices], dataset[test_indices]

# %%
train_ds_pd, validation_ds_pd = test_train_split(df)
print("{} examples in training, {} examples in testing.".format(
    len(train_ds_pd), len(validation_ds_pd)))
# Out:
# 9239 examples in training, 1041 examples in testing.

# %%
sentiment_labels = np.array(train_ds_pd['Sentiment'])
sentiment_labels
# Out:
# array(['negative', 'neutral', 'neutral', ..., 'negative', 'positive',
#        'negative'], dtype=object)

# %%
train_ds_pd = df
train_ds_pd = train_ds_pd.reset_index(drop=True)
validation_ds_pd = validation_ds_pd.reset_index(drop=True)

# %%
train_ds_pd.drop(columns=['Sentiment'], inplace=True)
validation_ds_pd.drop(columns=['Sentiment'], inplace=True)

# %%
sentiment_indexed_labels = np.array([sentiment_polarity_label_mapping_rev[label] for label in sentiment_labels])
sentiment_indexed_labels
# Out:
# array([0, 1, 1, ..., 0, 2, 0])

# %%
import torch
import torch.nn
import torch.nn as nn

# %%
class_counts = np.bincount(sentiment_indexed_labels)
total_samples = len(sentiment_labels)
class_weights = total_samples / (len(class_counts) * class_counts)
class_weights = class_weights / class_weights.sum()
class_weights = torch.tensor(class_weights, dtype=torch.float)
class_weights
# Out:
# tensor([0.2625, 0.3278, 0.4096])

# %% [markdown]
# ### SETTING CUDA

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from transformers import RobertaTokenizer, RobertaModel, DataCollatorWithPadding
from transformers import DebertaV2Model, DebertaV2Tokenizer, DebertaV2ForSequenceClassification
from torch.utils.data import Dataset, DataLoader

# %%
# tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
# tokenizer = DebertaV2Tokenizer.from_pretrained('microsoft/deberta-v3-base')

# %%
# !pip install optuna

# %% [markdown]
# ## TORCH IMPORTS

# %%
from torch.optim import AdamW
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaTokenizer, RobertaModel
from sklearn.model_selection import train_test_split
import optuna
# from optuna.integration import PyTorchLightningPruner
from ray import tune
import ray
from ray import tune
from ray.tune import CLIReporter
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
from ray.tune.schedulers import ASHAScheduler
# from ray.tune.integration.pytorch import TuneReportCallback
from torch.amp import GradScaler, autocast
# from ray.tune.integration.optuna import OptunaSearch
from ray.tune.search.optuna import OptunaSearch
from ray import tune
from ray.tune.search.hyperopt import HyperOptSearch
from torch import autocast
# from ray import tune
# from ray.tune.integration.tensorboard import TensorBoardReporter
from ray.tune.logger import TBXLogger
from torch.utils.tensorboard import SummaryWriter
from ray.train import report
# from ray.tune.integration.jupyter import JupyterNotebookReporter
from ray.tune import JupyterNotebookReporter
# from torch.cuda.amp import GradScaler, autocast
from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR
from ray.tune.schedulers import HyperBandScheduler, AsyncHyperBandScheduler

# %% [markdown]
# # DATASET CONFIG & ENCODING

# %%
# class SentimentDataset(Dataset):
#     def __init__(self, df, tokenizer):
#         self.df = df
#         self.tokenizer = tokenizer

#     def __len__(self):
#         return len(self.df)

#     def __getitem__(self, idx):
#         row = self.df.iloc[idx]
#         text = row["Informal Text"]
#         labels = torch.tensor(row[["negative", "neutral", "positive"]].values, dtype=torch.float32)

#         encoding = self.tokenizer(text, truncation=True, padding=False, return_tensors="pt")  # No padding, handled later
#         return {key: val.squeeze(0) for key, val in encoding.items()}, labels

# %%
def tokenize_function(examples):
    tokens = tokenizer(examples["Informal Text"], truncation=False, padding=False)  # No padding, done later
    labels = torch.tensor([
        examples["negative"], examples["neutral"], examples["positive"]
    ], dtype=torch.float32)
    return {**tokens, "labels": labels}

# %%
# class EmotionDataset(Dataset):
#     def __init__(self, dataframe, tokenizer, max_len = 2048):
#         self.tokenizer = tokenizer
#         self.data = dataframe
#         self.max_len = max_len

#     def __len__(self):
#         return len(self.data)

#     def __getitem__(self, index):
#         text = str(self.data.iloc[index]['Informal Text'])
#         labels = self.data.iloc[index][['anger', 'disgust', 'fear', 'joy', 'neutral', 'sadness', 'surprise']].values.astype(np.float32)
#         return {"text": text, "labels": labels}

# %%
def preprocess_function(examples):
    return tokenizer(examples['Informal Text'], padding="longest", truncation=False)

# %%
from transformers import AutoModel, AutoTokenizer, AutoConfig
from safetensors.torch import save_file, load_file
from huggingface_hub import hf_hub_download

# %%
# class DebertaForEmotionRegression(nn.Module):
#     def __init__(self, model_name=DebertaV2ForSequenceClassification.from_pretrained(
#         MODEL_NAME, 
#         num_labels=7,
#         device_map=torch.device("cuda" if torch.cuda.is_available() else "cpu")), num_labels=7):
#         super().__init__()
#         self.deberta = DebertaV2Model.from_pretrained(model_name)
#         self.dropout = nn.Dropout(0.1)
#         self.regressor = nn.Linear(self.deberta.config.hidden_size, num_labels)
    
#     def forward(self, input_ids, attention_mask, labels=None):
#         outputs = self.deberta(input_ids=input_ids, attention_mask=attention_mask)
#         pooled_output = outputs.last_hidden_state[:, 0, :]  # CLS token
#         pooled_output = self.dropout(pooled_output)
#         logits = self.regressor(pooled_output)  # No softmax, direct float output

#         loss = None
#         if labels is not None:
#             loss_fct = nn.MSELoss()
#             loss = loss_fct(logits, labels)
        
#         return {"loss": loss, "logits": logits} if loss is not None else {"logits": logits}

# %% [markdown]
# ## NEW TRAIN & VALIDATION 2.0
# ### Custom metric is a metric for determining the best model free from any overfitting, underfitting. ```custom_metric = (avg_val_loss−val_accuracy) + α × ∣avg_train_loss−avg_val_loss∣ + β × ∣val_accuracy-train_accuracy∣``` This metric balances between low validation loss, high validation accuracy, and penalizing large discrepancies between training and validation loss. Note that, in the model selection we have used ```α = β = 0.5```

# %% [markdown]
# ### But since, we have probabilistic values as input and output we cannot directly calculate the accuracy, infact we need to rely on loss only. ```custom_metric = avg_val_loss + α × ∣avg_train_loss−avg_val_loss∣```

# %%
# Custom metric calculation function
def calculate_custom_metric(avg_val_loss, avg_train_loss, alpha=0.5):
    loss_diff = abs(avg_train_loss - avg_val_loss)
    custom_metric = avg_val_loss + alpha * loss_diff
    return custom_metric

# %%
# # Custom metric calculation function
# def calculate_custom_metric(avg_val_loss, val_accuracy, avg_train_loss, train_accuracy, alpha=0.5, beta=0.5):
#     loss_diff = abs(avg_train_loss - avg_val_loss)
#     accuracy_diff = abs(train_accuracy - val_accuracy)
#     custom_metric = avg_val_loss - val_accuracy + alpha * loss_diff + beta * accuracy_diff
#     return custom_metric

# %% [markdown]
# # Model & Tokenizer

# %%
MODEL_NAME = 'microsoft/deberta-v3-base'

# %%
tokenizer = DebertaV2Tokenizer.from_pretrained(MODEL_NAME)
# Out:
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]

# %%
model = DebertaV2ForSequenceClassification.from_pretrained(
    MODEL_NAME, 
    num_labels=3,
    device_map=torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    problem_type="regression",
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# data_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="pt")

# %%
from datasets import Dataset

# %%
train_dataset = Dataset.from_pandas(train_ds_pd)
val_dataset = Dataset.from_pandas(validation_ds_pd)

# %%
# train_dataset1 = train_dataset.map(preprocess_function)
# val_dataset1 = val_dataset.map(preprocess_function)

# %%
df.columns
# Out:
# Index(['Informal Text', 'Sentiment', 'negative', 'neutral', 'positive'], dtype='object')

# %%
train_dataset1 = train_dataset.map(tokenize_function, remove_columns=['Informal Text', 'negative', 'neutral', 'positive'])
val_dataset1 = val_dataset.map(tokenize_function, remove_columns=['Informal Text', 'negative', 'neutral', 'positive'])
# Out:
# Map:   0%|          | 0/10280 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1041 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="pt")

# %%
# def collate_fn(batch):
#     inputs = [item[0] for item in batch]  
#     labels = torch.stack([item[1] for item in batch])  # Stack labels into (batch_size, 7)
    
#     # Use HF's DataCollatorWithPadding for dynamic padding
#     collator = DataCollatorWithPadding(tokenizer)
#     batch_inputs = collator(inputs)
    
#     batch_inputs["labels"] = labels  # Add labels separately
#     return batch_inputs

# %%
# train_dataset1 = EmotionDataset(train_dataset, tokenizer)
# val_dataset1 = EmotionDataset(val_dataset, tokenizer)

# %%
data_collator = DataCollatorWithPadding(tokenizer)

# %%
from torch.utils.tensorboard import SummaryWriter
# **TensorBoard Logging**
log_dir = "/kaggle/working/logs"
writer = SummaryWriter(log_dir=log_dir)

# %% [markdown]
# # Training

# %% [markdown]
# ## Training Arguments

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./deberta-lv1-checkpoints",
    eval_strategy="steps",  # Evaluate at regular intervals
    save_strategy="steps",  # Save model checkpoints at regular steps
    logging_strategy="steps",  # Log at regular steps
    logging_dir="/kaggle/working/logs",  # Directory for TensorBoard logs
    logging_steps=100,  # Log loss/metrics every 50 steps
    log_level="debug",
    save_total_limit=2,  # Keep only the 2 latest checkpoints
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    gradient_accumulation_steps=1,
    learning_rate=5e-5,
    weight_decay=0.01,
    num_train_epochs=15,
    lr_scheduler_type="linear",
    warmup_steps=50,
    fp16=True,  # Mixed precision for efficiency
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    report_to=["tensorboard"],
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset1,
    eval_dataset=val_dataset1,
    tokenizer=tokenizer,
    data_collator=data_collator  # Ensures dynamic padding
)


trainer.train()
# Out:
# <ipython-input-58-f38e9ed159e4>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# You have loaded a model on multiple GPUs. `is_model_parallel` attribute will be force-set to `True` to avoid any unexpected behavior such as device placement mismatching.
# Using auto half precision backend
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 10,280
#   Num Epochs = 15
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 19,275
#   Number of trainable parameters = 184,424,451
#     <div>
#
#       <progress value='19275' max='19275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [19275/19275 51:46, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.214600</td>
#       <td>0.224322</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.146400</td>
#       <td>0.116339</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.135900</td>
#       <td>0.097216</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.125800</td>
#       <td>0.094567</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.108500</td>
#       <td>0.091111</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.115600</td>
#       <td>0.084443</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.104600</td>
#       <td>0.095593</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.106800</td>
#       <td>0.078246</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.100300</td>
#       <td>0.098604</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.112000</td>
#       <td>0.071533</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.107200</td>
#       <td>0.079684</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.101700</td>
#       <td>0.065293</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.102700</td>
#       <td>0.070096</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.078400</td>
#       <td>0.069557</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.083400</td>
#       <td>0.066726</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.072100</td>
#       <td>0.059906</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.083400</td>
#       <td>0.051512</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.074700</td>
#       <td>0.046684</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.073500</td>
#       <td>0.064459</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.076700</td>
#       <td>0.054312</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.068100</td>
#       <td>0.052865</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.083900</td>
#       <td>0.049632</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.081900</td>
#       <td>0.057499</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.069800</td>
#       <td>0.044510</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.077300</td>
#       <td>0.055146</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.077200</td>
#       <td>0.055710</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.049100</td>
#       <td>0.040235</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.055100</td>
#       <td>0.042400</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.048800</td>
#       <td>0.040609</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.044900</td>
#       <td>0.040572</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.046300</td>
#       <td>0.036909</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.053500</td>
#       <td>0.046199</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.057500</td>
#       <td>0.035360</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.050900</td>
#       <td>0.042461</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.061100</td>
#       <td>0.039047</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.045100</td>
#       <td>0.045519</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.056500</td>
#       <td>0.041817</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.053700</td>
#       <td>0.044373</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.034200</td>
#       <td>0.036776</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.043300</td>
#       <td>0.035639</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.043200</td>
#       <td>0.032977</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.032700</td>
#       <td>0.036687</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.036600</td>
#       <td>0.045279</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.035900</td>
#       <td>0.034541</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.033600</td>
#       <td>0.042649</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.036400</td>
#       <td>0.034741</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.042700</td>
#       <td>0.033859</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.027600</td>
#       <td>0.036538</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.034500</td>
#       <td>0.032235</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.038300</td>
#       <td>0.022835</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.042500</td>
#       <td>0.026816</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.030700</td>
#       <td>0.030281</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.032000</td>
#       <td>0.023656</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.024400</td>
#       <td>0.027094</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.025300</td>
#       <td>0.021823</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.018100</td>
#       <td>0.028300</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.020400</td>
#       <td>0.019577</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.030700</td>
#       <td>0.020720</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.024900</td>
#       <td>0.024870</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.026000</td>
#       <td>0.019008</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.026100</td>
#       <td>0.025277</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.029500</td>
#       <td>0.017502</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.031900</td>
#       <td>0.021392</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.028200</td>
#       <td>0.020810</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.021100</td>
#       <td>0.022057</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.025700</td>
#       <td>0.023721</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>0.020800</td>
#       <td>0.020010</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.022000</td>
#       <td>0.014982</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.019900</td>
#       <td>0.015855</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.018300</td>
#       <td>0.014650</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>0.019300</td>
#       <td>0.013633</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.022000</td>
#       <td>0.015699</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>0.019800</td>
#       <td>0.014107</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.018100</td>
#       <td>0.014870</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.021600</td>
#       <td>0.014443</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.021300</td>
#       <td>0.016437</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>0.022100</td>
#       <td>0.011917</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.012700</td>
#       <td>0.013318</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>0.011700</td>
#       <td>0.011584</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.017600</td>
#       <td>0.011928</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.013600</td>
#       <td>0.019051</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.014600</td>
#       <td>0.013673</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>0.015800</td>
#       <td>0.014707</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.016600</td>
#       <td>0.013277</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.015700</td>
#       <td>0.014456</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.020000</td>
#       <td>0.012462</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.012100</td>
#       <td>0.015569</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.018000</td>
#       <td>0.0
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-500/added_tokens.json
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-1000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-1000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-1000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-1000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-1000/added_tokens.json
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-1500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-1500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-1500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-1500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-1500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-2000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-2000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-2000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-2000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-2000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-1000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-2500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-2500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-2500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-2500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-2500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-1500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-3000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-3000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-3000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-3000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-3000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-2000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-3500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-3500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-3500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-3500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-3500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-2500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-4000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-4000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-4000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-4000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-4000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-3000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-4500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-4500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-4500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-4500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-4500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-3500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-5000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-5000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-5000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-5000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-5000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-4000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-5500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-5500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-5500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-5500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-5500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-4500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-6000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-6000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-6000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-6000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-6000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-5000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-6500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-6500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-6500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-6500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-6500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-5500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-7000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-7000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-7000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-7000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-7000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-6000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-7500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-7500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-7500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-7500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-7500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-6500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-8000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-8000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-8000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-8000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-8000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-7000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-8500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-8500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-8500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-8500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-8500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-7500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-9000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-9000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-9000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-9000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-9000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-8000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-9500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-9500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-9500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-9500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-9500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-8500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-10000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-10000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-10000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-10000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-10000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-9000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-10500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-10500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-10500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-10500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-10500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-9500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-11000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-11000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-11000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-11000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-11000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-10000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-11500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-11500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-11500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-11500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-11500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-10500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-12000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-12000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-12000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-12000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-12000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-11000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-12500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-12500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-12500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-12500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-12500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-11500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-13000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-13000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-13000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-13000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-13000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-12000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-13500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-13500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-13500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-13500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-13500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-12500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-14000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-14000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-14000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-14000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-14000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-13000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-14500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-14500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-14500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-14500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-14500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-13500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-15000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-15000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-15000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-15000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-15000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-14000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-15500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-15500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-15500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-15500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-15500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-14500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-16000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-16000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-16000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-16000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-16000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-15000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-16500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-16500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-16500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-16500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-16500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-15500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-17000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-17000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-17000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-17000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-17000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-16000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-17500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-17500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-17500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-17500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-17500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-16500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-18000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-18000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-18000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-18000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-18000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-17000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-18500
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-18500/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-18500/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-18500/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-18500/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-17500] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-19000
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-19000/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-19000/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-19000/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-19000/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-18000] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
#
# ***** Running Evaluation *****
#   Num examples = 1041
#   Batch size = 8
# Saving model checkpoint to ./deberta-lv1-checkpoints/checkpoint-19275
# Configuration saved in ./deberta-lv1-checkpoints/checkpoint-19275/config.json
# Model weights saved in ./deberta-lv1-checkpoints/checkpoint-19275/model.safetensors
# tokenizer config file saved in ./deberta-lv1-checkpoints/checkpoint-19275/tokenizer_config.json
# Special tokens file saved in ./deberta-lv1-checkpoints/checkpoint-19275/special_tokens_map.json
# added tokens file saved in ./deberta-lv1-checkpoints/checkpoint-19275/added_tokens.json
# Deleting older checkpoint [deberta-lv1-checkpoints/checkpoint-18500] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./deberta-lv1-checkpoints/checkpoint-17400 (score: 0.004695110023021698).
# Could not locate the best model at ./deberta-lv1-checkpoints/checkpoint-17400/pytorch_model.bin, if you are running a distributed training on multiple nodes, you should activate `--save_on_each_node`.
# TrainOutput(global_step=19275, training_loss=0.02680858976994043, metrics={'train_runtime': 3107.1688, 'train_samples_per_second': 49.627, 'train_steps_per_second': 6.203, 'total_flos': 2135820359368800.0, 'train_loss': 0.02680858976994043, 'epoch': 15.0})

# %% [markdown]
# # Save the best model

# %%
from transformers import AutoModel, AutoTokenizer, AutoConfig
from safetensors.torch import save_file, load_file
from huggingface_hub import hf_hub_download

# %%
model.save_pretrained("/kaggle/working/deberta_seqcls_lv1_finetuned")
tokenizer.save_pretrained("/kaggle/working/deberta_seqcls_lv1_finetuned")
print("Model saved successfully!")
# Out:
# Configuration saved in /kaggle/working/deberta_seqcls_lv1_finetuned/config.json
# Model weights saved in /kaggle/working/deberta_seqcls_lv1_finetuned/model.safetensors
# tokenizer config file saved in /kaggle/working/deberta_seqcls_lv1_finetuned/tokenizer_config.json
# Special tokens file saved in /kaggle/working/deberta_seqcls_lv1_finetuned/special_tokens_map.json
# added tokens file saved in /kaggle/working/deberta_seqcls_lv1_finetuned/added_tokens.json
# Model saved successfully!

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
# secret_value_0 = user_secrets.get_secret("HF_READ_TOKEN")
# secret_value_1 = user_secrets.get_secret("HF_READ_WRITE_TOKEN")

# %%
from huggingface_hub import login

login(token=user_secrets.get_secret("HF_READ_TOKEN"))

# %%
from huggingface_hub import login

# Replace 'your_hf_token' with your actual Hugging Face API token
login(token=user_secrets.get_secret("HF_READ_WRITE_TOKEN"))

# %%
from huggingface_hub import HfApi, create_repo, upload_folder

# Define your Hugging Face repo ID
repo_id = "tachygraphy-microtrext-norm-org/DeBERTa-v3-seqClassfication-LV1-SentimentPolarities-Batch8"  # Example

# Local directory where all your model files are stored
local_model_dir = "/kaggle/working/deberta_seqcls_lv1_finetuned"

# Initialize API instance
api = HfApi()

# Create the repo if it doesn't exist
create_repo(repo_id, exist_ok=True)

# Upload all the files from the local directory to the Hugging Face Hub
upload_folder(
    folder_path=local_model_dir,  # Path to the folder to upload
    repo_id=repo_id,              # Repo ID on Hugging Face
    repo_type="model"             # Specify it's a model repo
)

print(f"All files uploaded to Hugging Face under {repo_id}")
# Out:
# model.safetensors:   0%|          | 0.00/738M [00:00<?, ?B/s]
# All files uploaded to Hugging Face under tachygraphy-microtrext-norm-org/DeBERTa-v3-seqClassfication-LV1-SentimentPolarities-Batch8

# %% [markdown]
# # PREDICT ON RANDOM INPUT

# %% [markdown]
# ## Prediction Function

# %%
# def predict(text, model, tokenizer, device, max_len=128):
#     # model.eval()  # Set model to evaluation mode

#     # Tokenize and pad the input text
#     inputs = tokenizer(
#         text,
#         None,
#         add_special_tokens=True,
#         padding=True,
#         truncation=False,
#         return_tensors="pt",
#         return_token_type_ids=False,
#     ).to(device)  # Move input tensors to the correct device

#     with torch.no_grad():
#         outputs = model(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"])

#     # Apply sigmoid activation (for BCEWithLogitsLoss)
#     probabilities = torch.sigmoid(outputs).cpu().numpy()

#     return probabilities

# %%
def predict(text, model, tokenizer, device, max_len=128):
    # model.eval()  # Set model to evaluation mode

    # Tokenize and pad the input text dynamically
    inputs = tokenizer(
        text,
        padding=True,  # Ensures correct padding for batch inference
        truncation=False,  # Prevents overly long sequences
        return_tensors="pt",
    ).to(device)  # Move input tensors to the correct device

    with torch.no_grad():
        outputs = model(**inputs)  # Forward pass

    # Extract logits (raw float values) directly
    predictions = outputs.logits.cpu().numpy()  

    return predictions

# %%
best_model = model
best_model = best_model.to(device)

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Samples & Random Predictions

# %%
# !pip install -U -q kaleido
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 21.5 MB/s eta 0:00:00

# %%
from IPython.display import Image

# %%
sample_text = "plz send the doc asap i need it by toni8"
predictions = predict(sample_text, best_model, tokenizer, device, max_len=128)
print(f"Predicted sentiment polarities for '{sample_text}': {predictions}")


predictions_array = predictions.squeeze()
binary_predictions = np.zeros_like(predictions_array)
max_indices = np.argmax(predictions_array)
binary_predictions[max_indices] = 1

print(f"NEAGTIVE: {binary_predictions[0]}, NEUTRAL: {binary_predictions[1]}, POSITIVE: {binary_predictions[2]}")

# labels = ['Negative', 'Neutral', 'Positive']



sentiment_polarities = []
for items in predictions_array:
    sentiment_polarities.append(items)

fig = px.line_polar(pd.DataFrame(dict(r=sentiment_polarities, theta=SENTIMENT_POLARITY_LABELS)), r='r', theta='theta', line_close=True)
# fig.show()

fig.show(renderer="png")  # Renders as PNG
fig.show(renderer="svg")  # Renders as SVG

# fig.write_image("/kaggle/working/sp_test1.png")

# Display the image (this will work for static rendering in platforms like Kaggle)

# Image("/kaggle/working/sp_test1.png")
# display(fig)


normalized_predictions = predictions_array / predictions_array.sum()

fig, ax = plt.subplots(figsize=(15, 5))

left = 0
for i in range(len(normalized_predictions)):
    ax.barh(0, normalized_predictions[i], color=plt.cm.tab10(i), left=left, label=SENTIMENT_POLARITY_LABELS[i])
    left += normalized_predictions[i]

# Add legend
ax.set_xlim(0, 1)
ax.set_yticks([])
ax.set_xticks(np.arange(0, 1.1, 0.1))
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=len(SENTIMENT_POLARITY_LABELS))

# Add title
plt.title('Sentiment Polarity Prediction Distribution')

plt.show()
# Out:
# Predicted sentiment polarities for 'plz send the doc asap i need it by toni8': [[ 0.00417709  1.0146484  -0.0418396 ]]
# NEAGTIVE: 0.0, NEUTRAL: 1.0, POSITIVE: 0.0

# %%
sample_text = "hey! hru, wanna ply valo toni8?"
predictions = predict(sample_text, best_model, tokenizer, device, max_len=128)
print(f"Predicted sentiment polarities for '{sample_text}': {predictions}")


predictions_array = predictions.squeeze()
binary_predictions = np.zeros_like(predictions_array)
max_indices = np.argmax(predictions_array)
binary_predictions[max_indices] = 1

print(f"NEAGTIVE: {binary_predictions[0]}, NEUTRAL: {binary_predictions[1]}, POSITIVE: {binary_predictions[2]}")

# labels = ['Negative', 'Neutral', 'Positive']



sentiment_polarities = []
for items in predictions_array:
    sentiment_polarities.append(items)

fig = px.line_polar(pd.DataFrame(dict(r=sentiment_polarities, theta=SENTIMENT_POLARITY_LABELS)), r='r', theta='theta', line_close=True)
# fig.show()

fig.show(renderer="png")  # Renders as PNG
fig.show(renderer="svg")  # Renders as SVG

# fig.write_image("/kaggle/working/sp_test2.png")

# Display the image (this will work for static rendering in platforms like Kaggle)

# Image("/kaggle/working/sp_test2.png")
# display(fig)


normalized_predictions = predictions_array / predictions_array.sum()

fig, ax = plt.subplots(figsize=(15, 5))

left = 0
for i in range(len(normalized_predictions)):
    ax.barh(0, normalized_predictions[i], color=plt.cm.tab10(i), left=left, label=SENTIMENT_POLARITY_LABELS[i])
    left += normalized_predictions[i]

# Add legend
ax.set_xlim(0, 1)
ax.set_yticks([])
ax.set_xticks(np.arange(0, 1.1, 0.1))
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=len(SENTIMENT_POLARITY_LABELS))

# Add title
plt.title('Sentiment Polarity Prediction Distribution')

plt.show()
# Out:
# Predicted sentiment polarities for 'hey! hru, wanna ply valo toni8?': [[-0.01605225  0.95751953  0.00577164]]
# NEAGTIVE: 0.0, NEUTRAL: 1.0, POSITIVE: 0.0

# %%
sample_text = "what a badass char is arthur, he is the best game char ever made, i luv rdr2"
predictions = predict(sample_text, best_model, tokenizer, device, max_len=128)
print(f"Predicted sentiment polarities for '{sample_text}': {predictions}")


predictions_array = predictions.squeeze()
binary_predictions = np.zeros_like(predictions_array)
max_indices = np.argmax(predictions_array)
binary_predictions[max_indices] = 1

print(f"NEAGTIVE: {binary_predictions[0]}, NEUTRAL: {binary_predictions[1]}, POSITIVE: {binary_predictions[2]}")

# labels = ['Negative', 'Neutral', 'Positive']



sentiment_polarities = []
for items in predictions_array:
    sentiment_polarities.append(items)

fig = px.line_polar(pd.DataFrame(dict(r=sentiment_polarities, theta=SENTIMENT_POLARITY_LABELS)), r='r', theta='theta', line_close=True)
# fig.show()

fig.show(renderer="png")  # Renders as PNG
fig.show(renderer="svg")  # Renders as SVG

# fig.write_image("/kaggle/working/sp_test3.png")

# Display the image (this will work for static rendering in platforms like Kaggle)

# Image("/kaggle/working/sp_test3.png")
# display(fig)


normalized_predictions = predictions_array / predictions_array.sum()

fig, ax = plt.subplots(figsize=(15, 5))

left = 0
for i in range(len(normalized_predictions)):
    ax.barh(0, normalized_predictions[i], color=plt.cm.tab10(i), left=left, label=SENTIMENT_POLARITY_LABELS[i])
    left += normalized_predictions[i]

# Add legend
ax.set_xlim(0, 1)
ax.set_yticks([])
ax.set_xticks(np.arange(0, 1.1, 0.1))
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=len(SENTIMENT_POLARITY_LABELS))

# Add title
plt.title('Sentiment Polarity Prediction Distribution')

plt.show()
# Out:
# Predicted sentiment polarities for 'what a badass char is arthur, he is the best game char ever made, i luv rdr2': [[0.00875092 0.00964355 1.0195312 ]]
# NEAGTIVE: 0.0, NEUTRAL: 0.0, POSITIVE: 1.0

# %%
sample_text = "I don't no fr y hes sooo sad."
predictions = predict(sample_text, best_model, tokenizer, device, max_len=128)
print(f"Predicted sentiment polarities for '{sample_text}': {predictions}")


predictions_array = predictions.squeeze()
binary_predictions = np.zeros_like(predictions_array)
max_indices = np.argmax(predictions_array)
binary_predictions[max_indices] = 1

print(f"NEAGTIVE: {binary_predictions[0]}, NEUTRAL: {binary_predictions[1]}, POSITIVE: {binary_predictions[2]}")

# labels = ['Negative', 'Neutral', 'Positive']



sentiment_polarities = []
for items in predictions_array:
    sentiment_polarities.append(items)

fig = px.line_polar(pd.DataFrame(dict(r=sentiment_polarities, theta=SENTIMENT_POLARITY_LABELS)), r='r', theta='theta', line_close=True)
# fig.show()

fig.show(renderer="png")  # Renders as PNG
fig.show(renderer="svg")  # Renders as SVG

# fig.write_image("/kaggle/working/sp_test4.png")

# Display the image (this will work for static rendering in platforms like Kaggle)

# Image("/kaggle/working/sp_test4.png")
# display(fig)


normalized_predictions = predictions_array / predictions_array.sum()

fig, ax = plt.subplots(figsize=(15, 5))

left = 0
for i in range(len(normalized_predictions)):
    ax.barh(0, normalized_predictions[i], color=plt.cm.tab10(i), left=left, label=SENTIMENT_POLARITY_LABELS[i])
    left += normalized_predictions[i]

# Add legend
ax.set_xlim(0, 1)
ax.set_yticks([])
ax.set_xticks(np.arange(0, 1.1, 0.1))
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=len(SENTIMENT_POLARITY_LABELS))

# Add title
plt.title('Sentiment Polarity Prediction Distribution')

plt.show()
# Out:
# Predicted sentiment polarities for 'I don't no fr y hes sooo sad.': [[ 0.98828125 -0.01381683  0.01210785]]
# NEAGTIVE: 1.0, NEUTRAL: 0.0, POSITIVE: 0.0
